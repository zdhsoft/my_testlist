# %% [markdown]
# # 安装报错：ModuleNotFoundError: No module named 'windows'
# ## 解决方案：
#     打开 python根目录\lib\site-packages\pymouse\__init__.py
#
#     把第92行的windows改为pymouse.windows并保存。

# %% [markdown]
# ![13.png](attachment:13.png)
